# %%
import librosa
import io    
import matplotlib.pyplot as plt                  
import librosa.display
import numpy
# India, Pakistan, Bangladesh, Bhutan, Nepal, Sri Lanka, Afghanistan, the Maldives,

# %%
audio_data = 'India.wav'                                                    
x,sr = librosa.load(audio_data) 
librosa.get_duration(x)

# %%
audio_data2 = 'Pakistan.wav'                                                    
x2,sr2 = librosa.load(audio_data2) 
librosa.get_duration(x2)
# Out:
# 78.4195918367347

# %%
audio_data3 = 'Bangladesh.wav'                                                    
x3,sr3 = librosa.load(audio_data3) 
librosa.get_duration(x3)
# Out:
# 94.03201814058957

# %%
audio_data4 = 'Nepal.wav'                                                    
x4,sr4 = librosa.load(audio_data4) 
librosa.get_duration(x4)
# Out:
# 47.307755102040815

# %%
audio_data5 = 'Sri Lanka.wav'                                                    
x5,sr5 = librosa.load(audio_data5) 
librosa.get_duration(x5)
# Out:
# 151.88403628117914

# %%
audio_data6 = 'Afghanistan.wav'                                                    
x6,sr6 = librosa.load(audio_data6) 
librosa.get_duration(x6)
# Out:
# 64.0

# %%
audio_data7 = 'Maldives.wav'                                                    
x7,sr7 = librosa.load(audio_data7) 
librosa.get_duration(x7)
# Out:
# 68.17959183673469

# %%
tempo, beat_times = librosa.beat.beat_track(x, sr=sr, start_bpm=60, units='time')
# %matplotlib inline
# Plot the beat locations over the waveform:
plt.figure(figsize=(14, 5))
plt.title("India")
librosa.display.waveplot(x, alpha=0.6)
plt.vlines(beat_times, -1, 1, color='r')
plt.ylim(-1, 1)

# Plot a histogram of the intervals between adjacent beats:
beat_times_diff = numpy.diff(beat_times)
plt.figure(figsize=(14, 5))
plt.hist(beat_times_diff, bins=50, range=(0,3))
plt.title("India")
plt.xlabel('Beat Length (seconds)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
tempo2, beat_times2 = librosa.beat.beat_track(x2, sr=sr2, start_bpm=60, units='time')

plt.figure(figsize=(14, 5))
librosa.display.waveplot(x2, alpha=0.6)
plt.vlines(beat_times2, -1, 1, color='r')
plt.ylim(-1, 1)

beat_times_diff2 = numpy.diff(beat_times2)
plt.figure(figsize=(14, 5))
plt.hist(beat_times_diff2, bins=50, range=(0,3))
plt.xlabel('Beat Length (seconds)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
tempo3, beat_times3 = librosa.beat.beat_track(x3, sr=sr3, start_bpm=60, units='time')

plt.figure(figsize=(14, 5))
librosa.display.waveplot(x3, alpha=0.6)
plt.vlines(beat_times3, -1, 1, color='r')
plt.ylim(-1, 1)

beat_times_diff3 = numpy.diff(beat_times3)
plt.figure(figsize=(14, 5))
plt.hist(beat_times_diff3, bins=50, range=(0,3))
plt.xlabel('Beat Length (seconds)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
tempo4, beat_times4 = librosa.beat.beat_track(x4, sr=sr4, start_bpm=60, units='time')

plt.figure(figsize=(14, 5))
librosa.display.waveplot(x4, alpha=0.6)
plt.vlines(beat_times4, -1, 1, color='r')
plt.ylim(-1, 1)

beat_times_diff4 = numpy.diff(beat_times4)
plt.figure(figsize=(14, 5))
plt.hist(beat_times_diff4, bins=50, range=(0,3))
plt.xlabel('Beat Length (seconds)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
tempo5, beat_times5 = librosa.beat.beat_track(x5, sr=sr5, start_bpm=60, units='time')

plt.figure(figsize=(14, 5))
librosa.display.waveplot(x5, alpha=0.6)
plt.vlines(beat_times5, -1, 1, color='r')
plt.ylim(-1, 1)

beat_times_diff5 = numpy.diff(beat_times5)
plt.figure(figsize=(14, 5))
plt.hist(beat_times_diff5, bins=50, range=(0,3))
plt.xlabel('Beat Length (seconds)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
tempo6, beat_times6 = librosa.beat.beat_track(x6, sr=sr6, start_bpm=60, units='time')
# %matplotlib inline
# Plot the beat locations over the waveform:
plt.figure(figsize=(14, 5))
plt.title("Afghanistan")
librosa.display.waveplot(x6, alpha=0.6)
plt.vlines(beat_times6, -1, 1, color='r')
plt.ylim(-1, 1)

# Plot a histogram of the intervals between adjacent beats:
beat_times_diff6 = numpy.diff(beat_times6)
plt.figure(figsize=(14, 5))
plt.hist(beat_times_diff6, bins=50, range=(0,3))
plt.title("Afghanistan")
plt.xlabel('Beat Length (seconds)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
tempo7, beat_times7 = librosa.beat.beat_track(x7, sr=sr7, start_bpm=60, units='time')
# %matplotlib inline
# Plot the beat locations over the waveform:
plt.figure(figsize=(14, 5))
plt.title("Maldives")
librosa.display.waveplot(x7, alpha=0.6)
plt.vlines(beat_times7, -1, 1, color='r')
plt.ylim(-1, 1)

# Plot a histogram of the intervals between adjacent beats:
beat_times_diff7 = numpy.diff(beat_times7)
plt.figure(figsize=(14, 5))
plt.hist(beat_times_diff7, bins=50, range=(0,3))
plt.title("Maldives")
plt.xlabel('Beat Length (seconds)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
